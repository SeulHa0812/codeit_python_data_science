# %%
import pandas as pd

# %%
df = pd.read_csv('data/test.csv')
df
# Out:
#          name  english_score  math_score  science_score
# 0     Hyesung           82.5        52.5           76.0
# 1      Gyujin           80.0        65.0           84.0
# 2     Sangwon           70.0        45.0           76.0
# 3      Minsoo           60.0        52.5           68.0
# 4      Jihwan           70.0        67.5           80.0
# 5        Jiho           80.0        32.5           68.0
# 6    Youngwoo           55.0        52.5           88.0
# 7     Junghun           57.5        75.0           88.0
# 8      Taewoo           62.5        75.0           74.0
# 9     Juhyeok           62.5        72.5           82.0
# 10      Taeho           41.0        50.0           68.0
# 11    Minchan           60.0        50.0           84.0
# 12     Sunwoo           70.0        55.0           70.0
# 13      Jimin           57.5        75.0           68.0
# 14     Minsoo           62.5        70.0           78.0
# 15  Seunghwan           41.0        62.5           76.0
# ...

# %%
df.describe() # 수치형 데이터만
# std(standard deviation)
# Out:
#        english_score  math_score  science_score
# count      25.000000   25.000000      25.000000
# mean       62.520000   62.000000      77.120000
# std        12.482054   13.346348       7.327573
# min        36.000000   32.500000      64.000000
# 25%        57.500000   52.500000      70.000000
# 50%        62.500000   65.000000      78.000000
# 75%        70.000000   72.500000      84.000000
# max        82.500000   85.000000      88.000000

# %%
df.describe(include='all') # 범주형 데이터까지 포함하고 싶다면
# Out:
#           name  english_score  math_score  science_score
# count       25      25.000000   25.000000      25.000000
# unique      24            NaN         NaN            NaN
# top     Minsoo            NaN         NaN            NaN
# freq         2            NaN         NaN            NaN
# mean       NaN      62.520000   62.000000      77.120000
# std        NaN      12.482054   13.346348       7.327573
# min        NaN      36.000000   32.500000      64.000000
# 25%        NaN      57.500000   52.500000      70.000000
# 50%        NaN      62.500000   65.000000      78.000000
# 75%        NaN      70.000000   72.500000      84.000000
# max        NaN      82.500000   85.000000      88.000000

# %%
# Box plot
import matplotlib.pyplot as plt

# %%
df2 = pd.read_csv('data/test_school.csv')
df2
# Out:
#      english_score  math_score  science_score
# 0             42.5        82.5           86.0
# 1             50.0        72.5           70.0
# 2             62.5        92.5           86.0
# 3             60.0        77.5           86.0
# 4             65.0        85.0           86.0
# ..             ...         ...            ...
# 295           65.0        32.5           84.0
# 296           67.5        80.0           80.0
# 297           65.0        55.0           70.0
# 298           57.5        65.0           84.0
# 299           40.0        65.0           80.0
#
# [300 rows x 3 columns]

# %%
df2['english_score']
# Out:
# 0      42.5
# 1      50.0
# 2      62.5
# 3      60.0
# 4      65.0
#        ...
# 295    65.0
# 296    67.5
# 297    65.0
# 298    57.5
# 299    40.0
# Name: english_score, Length: 300, dtype: float64

# %%
df2['english_score'].describe()
# Out:
# count    300.000000
# mean      62.295667
# std       10.528884
# min       27.000000
# 25%       57.500000
# 50%       62.500000
# 75%       70.000000
# max       97.000000
# Name: english_score, dtype: float64

# %%
df2['english_score'].plot(kind='box')
plt.show()

# %%
q1 = df2['english_score'].quantile(0.25)
q3 = df2['english_score'].quantile(0.75)
iqr = q3 - q1

# %%
q1 - 1.5 * iqr
# Out:
# np.float64(38.75)

# %%
q3 + 1.5 * iqr
# Out:
# np.float64(88.75)

# %%
df2.plot(kind='box')
plt.show()

# %%
df2[['math_score', 'science_score']].plot(kind='box')
plt.show()

# %%
# 히스토그램
df3 = pd.read_csv('data/body.csv')
df3
# Out:
#      height  weight
# 0     188.3    85.8
# 1     176.2    78.0
# 2     175.9    75.6
# 3     181.1    85.1
# 4     182.6    82.3
# ..      ...     ...
# 495   172.0    70.0
# 496   169.6    83.0
# 497   163.3    68.6
# 498   185.7    95.6
# 499   167.7    76.7
#
# [500 rows x 2 columns]

# %%
df3['height'].plot(kind='hist', bins=15)
plt.show()

# %%
df4 = pd.read_csv('data/car.csv')
df4
# Out:
#         manufacturer   category fuel_type  engine_volume  mileage  price
# 0            HYUNDAI       Jeep    Petrol            2.0    36800  36065
# 1             TOYOTA      Sedan    Petrol            2.5   107000  15053
# 2             NISSAN       Jeep    Petrol            1.6   108222   7527
# 3                BMW       Jeep    Diesel            3.0    18000  15681
# 4      MERCEDES-BENZ  Hatchback    Petrol            1.7   160000  13485
# ...              ...        ...       ...            ...      ...    ...
# 12014         TOYOTA  Hatchback    Hybrid            1.5   181474  14831
# 12015      CHEVROLET       Jeep    Diesel            2.0    70922  41055
# 12016        HYUNDAI       Jeep    Diesel            2.0   273371  27858
# 12017          LEXUS       Jeep       LPG            4.7   170000  34497
# 12018  MERCEDES-BENZ      Coupe    Petrol            2.3   157000   7213
#
# [12019 rows x 6 columns]

# %%
hyundai = df4.loc[df4['manufacturer'] == 'HYUNDAI']
plt.hist(hyundai['price'])
# Out:
# (array([1256., 1037.,  498.,  315.,   78.,   19.,   11.,   11.,    2.,
#            2.]),
#  array([  5018.,  17647.,  30276.,  42905.,  55534.,  68163.,  80792.,
#          93421., 106050., 118679., 131308.]),
#  <BarContainer object of 10 artists>)
