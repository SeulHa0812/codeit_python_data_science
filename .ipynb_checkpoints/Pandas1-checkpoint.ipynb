# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({
    'category': ['skirt', 'sweater', 'coat', 'jeans'],
    'quantity': [10, 15, 6, 11],                                     
    'price': [30000, 60000, 95000, 35000]
})
df
# Out:
#   category  quantity  price
# 0    skirt        10  30000
# 1  sweater        15  60000
# 2     coat         6  95000
# 3    jeans        11  35000

# %%
df['quantity'] # column으로 조회
# Out:
# 0    10
# 1    15
# 2     6
# 3    11
# Name: quantity, dtype: int64

# %%
type(df['quantity'])
# 1차원 배열 = 한 줄로 된 데이터, 구조: [1, 2, 3, 4]
# 2차원 배열 = 행+열 표 형태
# Out:
# pandas.core.series.Series

# %%
print(df['quantity'].mean())
print(df['quantity'].sum())
print(df['quantity'].min())
# Out:
# 10.5
# 42
# 6

# %%
df['quantity'] * df['price'] # 새로운 series 반환
# Out:
# 0    300000
# 1    900000
# 2    570000
# 3    385000
# dtype: int64

# %%
# DataFrame 만드는 다양한 방법
dict_df = pd.DataFrame({
    'category': ['skirt', 'sweater', 'coat', 'jeans'],
    'quantity': [10, 15, 6, 11],                                     
    'price': [30000, 60000, 95000, 35000]
})

# %%
two_dimensional_list = [
    ['skirt', 10, 30000],
    ['sweater', 15, 60000],
    ['coat', 6, 95000],
    ['jeans', 11, 35000]
]
two_dimensional_array = np.array(two_dimensional_list)

list_df = pd.DataFrame(two_dimensional_list)
array_df = pd.DataFrame(two_dimensional_array)
print(list_df)
print(array_df)
# Out:
#          0   1      2
# 0    skirt  10  30000
# 1  sweater  15  60000
# 2     coat   6  95000
# 3    jeans  11  35000
#          0   1      2
# 0    skirt  10  30000
# 1  sweater  15  60000
# 2     coat   6  95000
# 3    jeans  11  35000

# %%
list_df = pd.DataFrame(two_dimensional_list, columns=['category', 'quantity', 'price'])
array_df = pd.DataFrame(two_dimensional_array, columns=['category', 'quantity', 'price'])
print(list_df)
print(array_df)
# Out:
#   category  quantity  price
# 0    skirt        10  30000
# 1  sweater        15  60000
# 2     coat         6  95000
# 3    jeans        11  35000
#   category quantity  price
# 0    skirt       10  30000
# 1  sweater       15  60000
# 2     coat        6  95000
# 3    jeans       11  35000

# %%
dict_list = [
    {'category': 'skirt', 'quantity': 10, 'price': 30000},
    {'category': 'sweater', 'quantity': 15, 'price': 60000},
    {'category': 'coat', 'quantity': 6, 'price': 95000},
    {'category': 'jeans', 'quantity': 11, 'price': 35000}
]

dict_list_df = pd.DataFrame(dict_list)
print(dict_list_df)
# Out:
#   category  quantity  price
# 0    skirt        10  30000
# 1  sweater        15  60000
# 2     coat         6  95000
# 3    jeans        11  35000
